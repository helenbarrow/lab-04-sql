# %%
import pandas as pd

df = pd.read_csv('MOCK_DATA.csv')

# %%
df.head()
# Out:
#    id         group  age        city   salary active
# 0   1  The Avengers   26  Ringinrejo  23032.0   True
# 1   2    Squadron X   95  Kalapagada  96167.0   True
# 2   3  The Avengers    4      Āstārā  77702.0  False
# 3   4       Group 1   73      Digdig  23447.0  False
# 4   5        Team A   98      Doujia  28282.0  False

# %%
df.dtypes
# Out:
# id          int64
# group         str
# age         int64
# city          str
# salary    float64
# active     object
# dtype: object

# %%
type_mapping = {
    "int64": "BIGINT",
    "int32": "INT",
    "float64": "DOUBLE",
    "bool": "TINYINT(1)",
    "datetime64[ns]": "DATETIME",
    "object": "VARCAR(255)",
    "string": "VARHAR(255)",
}
